# %% [markdown]
# <a href="https://colab.research.google.com/github/OliverZarate/Actividad-1-Extracci-n-de-Datos-/blob/main/Actividad_1(Extraccion_de_datos).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-9b974619-f7a3-413b-9442-998f6377a93d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9b974619-f7a3-413b-9442-998f6377a93d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_excel("/content/Antigüedad de saldos 17.03.2023.xlsx")
df
# Out:
#     No. CLIENTE                                             NOMBRE  FACTURA  \
# 0          6401                               DONGA HWASUNG MEXICO   F40238
# 1          6401                               DONGA HWASUNG MEXICO   F40353
# 2          4598       PROVEEDORA DE SEGURIDAD INDUSTRIAL DEL GOLFO   F40352
# 3          3930                               INDUSTRIAS LANCERMEX   F40217
# 4          4712                                             HELVEX   F40173
# ..          ...                                                ...      ...
# 159         856  CENTRO DE INVESTIGACION Y DE ESTUDIOS AVANZADO...   F40055
# 160        5926                                 PÚBLICO EN GENERAL  NV00777
# 161        5926                                 PÚBLICO EN GENERAL  NV00778
# 162        5926                                 PÚBLICO EN GENERAL  NV00779
# 163        8429                                  FISHERS QUERETARO   F38248
#
#     FECHA_FACTURA FECHA_VENCIMIENTO  MONTO ADEUDADO
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 164 entries, 0 to 163
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   No. CLIENTE        162 non-null    object
#  1   NOMBRE             163 non-null    object
#  2   FACTURA            163 non-null    object
#  3   FECHA_FACTURA      163 non-null    datetime64[ns]
#  4   FECHA_VENCIMIENTO  164 non-null    datetime64[ns]
#  5   MONTO ADEUDADO     163 non-null    float64
# dtypes: datetime64[ns](2), float64(1), object(3)
# memory usage: 7.8+ KB

# %%
df.head()
# Out:
#   No. CLIENTE                                        NOMBRE FACTURA  \
# 0        6401                          DONGA HWASUNG MEXICO  F40238
# 1        6401                          DONGA HWASUNG MEXICO  F40353
# 2        4598  PROVEEDORA DE SEGURIDAD INDUSTRIAL DEL GOLFO  F40352
# 3        3930                          INDUSTRIAS LANCERMEX  F40217
# 4        4712                                        HELVEX  F40173
#
#   FECHA_FACTURA FECHA_VENCIMIENTO  MONTO ADEUDADO
# 0    2023-02-24        2023-03-26        97485.94
# 1    2023-03-14        2023-04-13        97485.94
# 2    2023-03-14        2023-04-13        64916.21
# 3    2023-02-23        2023-03-25        52715.74
# 4    2023-02-17        2023-04-03        50639.80

# %% [markdown]
# ****************Filtros para variables cualitativas***

# %%
#Filtro por objeto
filtro1=df[df["NOMBRE"]=="INDUSTRIAS LANCERMEX"]
filtro1
# Out:
#    No. CLIENTE                NOMBRE FACTURA FECHA_FACTURA FECHA_VENCIMIENTO  \
# 3         3930  INDUSTRIAS LANCERMEX  F40217    2023-02-23        2023-03-25
# 12        3930  INDUSTRIAS LANCERMEX  F40114    2023-02-09        2023-03-11
#
#     MONTO ADEUDADO
# 3         52715.74
# 12        35143.82

# %%
#Filtro por filas
#filtro2 = df.iloc[3:11,:]
filtro2= df.iloc[[8, 24, 100] , :]
filtro2
# Out:
#     No. CLIENTE                  NOMBRE FACTURA FECHA_FACTURA  \
# 8           644   CLAVOS NACIONALES C.N  F40340    2023-03-13
# 24         8708       TE.MEX AUTOMOTIVE  F40183    2023-02-20
# 100        3926  PRODUCTOS PENNSYLVANIA  F40357    2023-03-14
#
#     FECHA_VENCIMIENTO  MONTO ADEUDADO
# 8          2023-05-12        45216.34
# 24         2023-03-13        22956.40
# 100        2023-04-13         2756.16

# %%
#Filtro por columnas
filtro3 = df.iloc[ : , 1:4]
filtro2= df.iloc[ : ,[1,4,5 ]]
filtro2
# Out:
#                                                 NOMBRE FECHA_VENCIMIENTO  \
# 0                                 DONGA HWASUNG MEXICO        2023-03-26
# 1                                 DONGA HWASUNG MEXICO        2023-04-13
# 2         PROVEEDORA DE SEGURIDAD INDUSTRIAL DEL GOLFO        2023-04-13
# 3                                 INDUSTRIAS LANCERMEX        2023-03-25
# 4                                               HELVEX        2023-04-03
# ..                                                 ...               ...
# 159  CENTRO DE INVESTIGACION Y DE ESTUDIOS AVANZADO...        2023-01-31
# 160                                 PÚBLICO EN GENERAL        2023-03-07
# 161                                 PÚBLICO EN GENERAL        2023-03-09
# 162                                 PÚBLICO EN GENERAL        2023-03-09
# 163                                  FISHERS QUERETARO        2022-05-27
#
#      MONTO ADEUDADO
# 0          97485.94
# 1          97485.94
# 2          64916.21
# ...
